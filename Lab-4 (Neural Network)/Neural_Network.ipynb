# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("cancer_data.csv")
df.head()
# Out:
#          id  radius_mean  texture_mean diagnosis
# 0    842302        17.99         10.38         M
# 1    842517        20.57         17.77         M
# 2  84300903        19.69         21.25         M
# 3  84348301        11.42         20.38         M
# 4  84358402        20.29         14.34         M

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for the plot
sns.set(style="whitegrid")

# Create the scatter plot
plt.figure(figsize=(6, 4))
sns.scatterplot(data=df, x='radius_mean', y='texture_mean', hue='diagnosis', palette='Set1', s=100)

# Add labels and title
plt.xlabel('Radius Mean')
plt.ylabel('Texture Mean')
plt.title('Scatter Plot of Radius Mean vs Texture Mean with Diagnosis Label')

# Show the plot
plt.show()

# %%
x1 = df['radius_mean'].to_numpy()
x2 = df['texture_mean'].to_numpy()
y =df['diagnosis'].to_numpy()

# %%
x = np.array([x1,x2])
x
# Out:
# array([[17.99, 20.57, 19.69, ..., 16.6 , 20.6 ,  7.76],
#        [10.38, 17.77, 21.25, ..., 28.08, 29.33, 24.54]])

# %%
w = np.array([0.2,0.1])
w
# Out:
# array([0.2, 0.1])

# %% [raw]
# def dence(w,x_train,b):
#     a = np.zeros((1,m))
#     z = np.dot(w,x_train) + b
#     sig_z = np.divide(1, (1 + np.exp(-z)))
#
#     for i in range(0,m):
#         if (sig_z[0,i] >= 0.5):
#             a[0,i] = 1
#         else:
#             a[0,i] = 0
#
#     return a

# %%
def dence(w,x_train,b):
    y_pred = np.dot(w,x_train) + b            
    return y_pred
